# %% [markdown]
# <h1 style="font-size:14px"> Li-Ion Battery Data Analysis</h1>
#
#
# <h2 style="font-size:14px">NASA battery B0005 dataset </h2>

# %% [markdown]
# <p><b>In this project, a dataset of commercial Type 1850 Lithium-ion batteries from the Prognostics Center of Excellence (PCoE), NASA is used.</b></p>
#
# <p>For battery #5 the capacity ratings is 2.0Ahr. In the experiment, the battery repeatedly underwent charge, discharge and impedance measure in the room temperature (24°C). Specifically:</p>
# <li>Charging: Charge the battery with constant electric current 1.5A until the voltage reached 4.2V. Then, charge it with constant voltage until the charging current decreased to 20mA. Stop charging.</li>
# <li>Discharging: Discharge with 2A current until the voltage declined to around 2.7V</li>
# <li>The experiment terminated when the capacity of the battery declined to about 70% of the capacity ratings (the given failure threshold)</li>
#
# <h3>Data Structure:</h3>

# %%
import pandas as pd

# %% [markdown]
# <h3>Import all files for battery B0005</h3>

# %%
charge = pd.read_csv('B0005_10_charge.csv')
discharge = pd.read_csv('B0005_10_discharge.csv')
imp = pd.read_csv('B0005_10_impedance.csv')
dis = pd.read_csv('B0005_discharge.csv')

# %%
# format datetime field which comes in as string
charge['dateTime'] = pd.to_datetime(charge['dateTime'])
discharge['dateTime'] = pd.to_datetime(discharge['dateTime'])
dis['dateTime']=pd.to_datetime(dis['dateTime'])

# %% [markdown]
# <h2>Dataset</h2>
#
# <p>The first data source is the charge time-series data which consists of <b>battery name, cycle, dateTime, ambient temperature, voltage_battery, current_battery, Temperature battery, current_load, voltage_load and time.</b></p>
# <li>Below, we display the first 5 records in the dataset. A summary of the whole dataset is also provided.</li>

# %%
#charge.drop(['Capacity'], axis=1, inplace=True)
print(len(discharge))
# Out:
# 50285

# %%
# we use .str to replace and then convert to float
# A summary of the whole dataset
print(charge.head())
charge.describe()
# Out:
#     Batt_name  cycle            dateTime  amb_temp  voltage_battery  \
# 0  'B0005_10'      1 2008-04-02 13:08:17        24         3.873017
# 1  'B0005_10'      1 2008-04-02 13:08:17        24         3.479394
# 2  'B0005_10'      1 2008-04-02 13:08:17        24         4.000588
# 3  'B0005_10'      1 2008-04-02 13:08:17        24         4.012395
# 4  'B0005_10'      1 2008-04-02 13:08:17        24         4.019708
#
#    current_battery  temp_battery  voltage_load  current_load    time  Capacity
# 0        -0.001201     24.655358         0.003         0.000   0.000       NaN
# 1        -4.030268     24.666480         1.570        -4.036   2.532       NaN
# 2         1.512731     24.675394         4.726         1.500   5.500       NaN
# 3         1.509063     24.693865         4.742         1.500   8.344       NaN
# 4         1.511318     24.705069         4.753         1.500  11.125       NaN
#                cycle  amb_temp  voltage_battery  current_battery  \
# count  541173.000000  541173.0    541173.000000    541173.000000
# mean       96.606471      24.0         4.158644         0.571543
# std        42.702483       0.0         0.098078         0.620454
# min         1.000000      24.0         0.003365        -4.479660
# 25%        62.000000      24.0         4.195473         0.058024
# 50%        97.000000      24.0         4.205310         0.227544
# 75%       133.000000      24.0         4.205978         1.506508
# max       170.000000      24.0         8.393141         1.531301
#
#         temp_battery   voltage_load   current_load           time  Capacity
# count  541173.000000  541173.000000  541173.000000  541173.000000       0.0
# mean       25.770628       4.184427       0.566810    5062.836059       NaN
# std         1.643729       1.112792       0.616015    3114.798871       NaN
# min        23.246728       0.003000      -4.468000       0.000000       NaN
# 25%        24.438659       4.250000       0.057000    2271.610000       NaN
# 50%        25.255235       4.332000       0.225000    4982.078000       NaN
# 75%        26.819807       4.688000       1.498000    7763.219000       NaN
# max        31.187718       5.002000       1.500000   10807.328000       NaN

# %% [markdown]
# <p> <b>The Graph below describe the standard deviation for all the features<b></p>

# %%
featurs=['voltage_battery','current_battery','temp_battery','current_load','voltage_load']
charge[featurs].std().plot(kind='bar', figsize=(8,6), title="Features Standard Deviation")

# %% [markdown]
# <br><br>
#
# <p>The second data source is the discharge time-series data which consists of <b> battery name, cycle, pressure, dateTime, ambient temperature, voltage_battery, current_battery,Temperature battery, current_load, voltage_load and time.</b></p>
# <li>Below, we display the first 5 records in the dataset. A summary of the whole dataset is also provided.</li>
#
# <br><br>

# %%
discharge['Capacity'] = discharge.Capacity.str.replace("'", '').astype(float)
print(discharge.head(5))
discharge.describe()
# Out:
#     Batt_name  cycle            dateTime  amb_temp  voltage_battery  \
# 0  'B0005_10'      1 2008-04-02 15:25:41        24         4.191492
# 1  'B0005_10'      1 2008-04-02 15:25:41        24         4.190749
# 2  'B0005_10'      1 2008-04-02 15:25:41        24         3.974871
# 3  'B0005_10'      1 2008-04-02 15:25:41        24         3.951717
# 4  'B0005_10'      1 2008-04-02 15:25:41        24         3.934352
#
#    current_battery  temp_battery  voltage_load  current_load    time  Capacity
# 0        -0.004902     24.330034         0.000       -0.0006   0.000  1.856487
# 1        -0.001478     24.325993         4.206       -0.0006  16.781  1.856487
# 2        -2.012528     24.389085         3.062       -1.9982  35.703  1.856487
# 3        -2.013979     24.544752         3.030       -1.9982  53.781  1.856487
# 4        -2.011144     24.731385         3.011       -1.9982  71.922  1.856487
#               cycle  amb_temp  voltage_battery  current_battery  temp_battery  \
# count  50285.000000   50285.0     50285.000000     50285.000000  50285.000000
# mean      88.125942      24.0         3.515268        -1.806032     32.816991
# std       45.699687       0.0         0.231778         0.610502      3.987515
# min        1.000000      24.0         2.455679        -2.029098     23.214802
# 25%       50.000000      24.0         3.399384        -2.013415     30.019392
# 50%       88.000000      24.0         3.511664        -2.012312     32.828944
# 75%      127.000000      24.0         3.660903        -2.011052     35.920887
# max      168.000000      24.0         4.222920         0.007496     41.450232
#
#        voltage_load  current_load          time      Capacity
# count  50285.000000  50285.000000  50285.000000  50285.000000
# mean       2.308406      1.362700   1546.208924      1.560345
# std        0.800300      1.313698    906.640295      0.182380
# min        0.000000     -1.998400      0.000000      1.287453
# 25%        2.388000      1.998000    768.563000      1.386229
# 50%        2.533000      1.998200   1537.031000      1.538237
# 75%        2.690000      1.998200   2305.984000      1.746871
# max        4.238000      1.998400   3690.234000      1.856487

# %%
discharge[featurs].std().plot(kind='bar', figsize=(8,6), title="Features Standard Deviation- Discharge Dataset")

# %% [markdown]
# <h3> Figure below shows capacity changes of the battery (B5) over the charge-discharge cycles.</h3>

# %%
attrib=['Batt_name','cycle','time','Capacity']
dis_ele=dis[attrib]
print(dis_ele.head())
# get ordered list features correlation with regression label ttf
#dis_ele[attrib].std().plot(kind='bar', figsize=(8,6), title="Features Standard Deviation")

#dis_ele[attrib].corrwith(dis_ele.Capacity).sort_values(ascending=False)
# Out:
#   Batt_name  cycle      time  Capacity
# 0  B0005_10      1  3690.234  1.856487
# 1  B0005_10      2  3672.344  1.846327
# 2  B0005_10      3  3651.641  1.835349
# 3  B0005_10      4  3631.563  1.835263
# 4  B0005_10      5  3629.172  1.834646

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plot_df = dis.loc[(dis['cycle']>=1),['cycle','Capacity']]
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))
plt.plot(plot_df['cycle'], plot_df['Capacity'])
#Draw threshold
plt.plot([0.,len(dis)], [1.4, 1.4])
plt.ylabel('Capacity')
# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
plt.xlabel('cycle')
plt.title('Discharge B0005')
# Out:
# Text(0.5, 1.0, 'Discharge B0005')

# %% [markdown]
# <p>Calculate The state of health of battery No.05:</p>
# SOH(τ)=C(τ)/C(0)
# <p>where C(0) is the capacity value at the initial stage of Li-ion battery, and C(τ) is the capacity value at time τ (it is usually the index of cycle number).</p>

# %%
attrib=['Batt_name','cycle','time','Capacity']
dis_ele=dis[attrib]
C=dis_ele['Capacity'][0]
#print(dis_ele['Capacity'][0])
HoS=0
for i in range(len(dis_ele)):
    dis_ele['SoH']=(dis_ele['Capacity'])/C
print(dis_ele.head(5))
# Out:
#   Batt_name  cycle      time  Capacity       SoH
# 0  B0005_10      1  3690.234  1.856487  1.000000
# 1  B0005_10      2  3672.344  1.846327  0.994527
# 2  B0005_10      3  3651.641  1.835349  0.988614
# 3  B0005_10      4  3631.563  1.835263  0.988567
# 4  B0005_10      5  3629.172  1.834646  0.988235

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plot_df = dis_ele.loc[(dis_ele['cycle']>=1),['cycle','SoH']]
sns.set_style("white")
plt.figure(figsize=(8, 5))
plt.plot(plot_df['cycle'], plot_df['SoH'])
#Draw threshold
#plt.plot([0.,len(dis)], [0.70, 0.70])
plt.ylabel('SOH')
# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
plt.xlabel('cycle')
plt.title('Discharge B0005')
# Out:
# Text(0.5, 1.0, 'Discharge B0005')

# %% [markdown]
# <h3>Plotting discharge data for B0005<h3>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plot_df = discharge.loc[(discharge['cycle']>=1),['time','voltage_battery']]
sns.set_style("darkgrid")
plt.figure(figsize=(20, 8))
plt.plot(plot_df['time'], plot_df['voltage_battery'])
plt.ylabel('voltage battery')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('Time')
plt.title('Discharge')
# Out:
# Text(0.5, 1.0, 'Discharge')

# %% [markdown]
# <p>The thrid data source is the impedance time-series data which consists of<b> battery name, cycle, dateTime, ambient temperature, Sense_current, Battery_current, Current_ratio, Battery_impedance, Estimated electrolyte resistance(re) and Estimated charge transfer resistance (rct).</b></p>
#
# <p><li>Below, we display the first 5 records in the dataset. A summary of the whole dataset is also provided.</li></p>

# %%
print(imp.head())
imp.describe()
# Out:
#     Batt_name  cycle                dateTime  amb_temp  sense_current_real  \
# 0  'B0005_10'      1   '2008-04-18 20:55:29'        24           -1.000000
# 1  'B0005_10'      1   '2008-04-18 20:55:29'        24          820.609497
# 2  'B0005_10'      1   '2008-04-18 20:55:29'        24          827.242188
# 3  'B0005_10'      1   '2008-04-18 20:55:29'        24          827.193481
# 4  'B0005_10'      1   '2008-04-18 20:55:29'        24          824.929504
#
#    sense_current_img  battery_current_real  battery_current_img  \
# 0           1.000000             -1.000000             1.000000
# 1         -36.234550            337.091461           -82.920776
# 2         -48.231228            330.631561           -70.013718
# 3         -56.195717            330.808624           -61.734425
# 4         -53.241478            332.682678           -57.629013
#
#    current_ratio_real  current_ratio_img  battery_impedance_real  \
# 0            1.000000           0.000000               -0.438926
# 1            2.320415           0.463305                0.130088
# 2            2.424193           0.367465                0.058771
# 3            2.447002           0.286778                0.005814
# 4            2.434305           0.261646                0.126081
#
#    battery_impedance_img        re       rct
# 0              -0.107298  0.044669  0.069456
# 1              -0.197115  0.044669  0.069456
# 2               0.033307  0.044669  0.069456
# 3              -0.060547  0.044669  0.069456
# 4              -0.090444  0.044669  0.069456
#               cycle  amb_temp  sense_current_real  sense_current_img  \
# count  13344.000000   13344.0        13344.000000       13344.000000
# mean     139.500000      24.0          836.231387         -25.478224
# std       80.254175       0.0           44.703595          92.871311
# min        1.000000      24.0           -1.000000        -121.028297
# 25%       70.000000      24.0          821.964249         -62.798315
# 50%      139.500000      24.0          829.064972         -43.926643
# 75%      209.000000      24.0          839.067459         -15.116543
# max      278.000000      24.0          926.239258         458.924774
#
#        battery_current_real  battery_current_img  current_ratio_real  \
# count          13344.000000         13344.000000        13344.000000
# mean             312.818696            -1.958398            2.634386
# std               56.516214            54.800995            0.479906
# min               -1.000000          -106.597794            1.000000
# 25%              319.091743           -34.719997            2.411979
# 50%              331.967834           -11.365921            2.480312
# 75%              340.217415             0.666376            2.589735
# max              496.963593           159.152161            4.943655
#
#        current_ratio_img  battery_impedance_real  battery_impedance_img  \
# count       13344.000000            13344.000000           13344.000000
# mean           -0.244941                0.211303              -0.017001
# std             0.707316                0.047824               0.039477
# min            -2.611762               -0.535516              -0.284150
# 25%            -0.130184                0.195171              -0.037786
# 50%             0.045310                0.205316              -0.004546
# 75%             0.080907                0.220205               0.002428
# max             0.650157                0.392987               0.208347
#
#                  re           rct
# count  13344.000000  13344.000000
# mean       0.054245      0.077340
# std        0.005480      0.006356
# min        0.043559      0.064883
# 25%        0.049159      0.071464
# 50%        0.055850      0.077487
# 75%        0.058820      0.082576
# max        0.063516      0.089757

# %% [markdown]
# <h3>Plotting impedance data for B0005- Charge transfer resistance over the number of cycles<h3>

# %%
plot_df = imp.loc[(imp['cycle']>=1),['cycle','rct']]
sns.set_style("darkgrid")
plt.figure(figsize=(20, 8))
plt.plot(plot_df['cycle'], plot_df['rct'])
plt.ylabel('Charge transfer resistance')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('Cycle')
plt.title('impedance')
# Out:
# Text(0.5, 1.0, 'impedance')

# %% [markdown]
# <h3>Plotting impedance data for B0005- Estimated electrolyte resistance over the number of cycles<h3>

# %%
plot_df = imp.loc[(imp['cycle']>=1),['cycle','re']]
sns.set_style("darkgrid")
plt.figure(figsize=(20, 8))
plt.plot(plot_df['cycle'], plot_df['re'])
plt.ylabel('Estimated electrolyte resistance')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('Cycle')
plt.title('impedance')
# Out:
# Text(0.5, 1.0, 'impedance')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
time12=charge['time'][788]
print(time12)
discharge['time']=discharge['time']+time12

plot_df = discharge.loc[(discharge['cycle']==1),['time','voltage_battery']]
plot_charge=charge.loc[(charge['cycle']==1),['time','voltage_battery']]
sns.set_style("darkgrid")
plt.figure(figsize=(20, 8))
plt.plot(plot_df['time'], plot_df['voltage_battery'])
plt.plot(plot_charge['time'], plot_charge['voltage_battery'])
#Draw threshold
#plt.plot(dis['cycle'], dis['limt']) 'g'
plt.ylabel('voltage battery')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('cycle')
plt.title('Discharge B0005 - Orange line: charge and  Blue line: Discharge')
# Out:
# 7597.875
# Text(0.5, 1.0, 'Discharge B0005 - Orange line: charge and  Blue line: Discharge')

# %%
all_data = pd.read_csv('B0005time.csv')
print(all_data.head())
# Out:
#     Batt_name  operation  cycle                dateTime  amb_temp  \
# 0  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 1  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 2  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 3  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 4  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
#
#    voltage_battery  current_battery  temp_battery  voltage_load  current_load  \
# 0         3.873017        -0.001201     24.655358         0.003         0.000
# 1         3.479394        -4.030268     24.666480         1.570        -4.036
# 2         4.000588         1.512731     24.675394         4.726         1.500
# 3         4.012395         1.509063     24.693865         4.742         1.500
# 4         4.019708         1.511318     24.705069         4.753         1.500
#
#      time Capacity
# 0   0.000    'nan'
# 1   2.532    'nan'
# 2   5.500    'nan'
# 3   8.344    'nan'
# 4  11.125    'nan'

# %%
featurs=['voltage_battery','current_battery','temp_battery','current_load','voltage_load','Capacity']
all_data[featurs].std().plot(kind='bar', figsize=(8,6), title="Features Standard Deviation")

# %%
# get ordered list of top variance features:

featurs_top_var = all_data[featurs].std().sort_values(ascending=False)
featurs_top_var
# Out:
# temp_battery       2.772424
# voltage_load       1.208825
# current_battery    0.907558
# current_load       0.737029
# voltage_battery    0.213469
# dtype: float64

# %%
print(all_data.head())
# Out:
#     Batt_name  operation  cycle                dateTime  amb_temp  \
# 0  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 1  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 2  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 3  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
# 4  'B0005_10'   'charge'      1   '2008-04-02 13:08:17'        24
#
#    voltage_battery  current_battery  temp_battery  voltage_load  current_load  \
# 0         3.873017        -0.001201     24.655358         0.003         0.000
# 1         3.479394        -4.030268     24.666480         1.570        -4.036
# 2         4.000588         1.512731     24.675394         4.726         1.500
# 3         4.012395         1.509063     24.693865         4.742         1.500
# 4         4.019708         1.511318     24.705069         4.753         1.500
#
#      time Capacity
# 0   0.000    'nan'
# 1   2.532    'nan'
# 2   5.500    'nan'
# 3   8.344    'nan'
# 4  11.125    'nan'

# %%
all_data['dateTime'] = pd.to_datetime(all_data['dateTime'])
all_data['operation']=all_data.operation.str.replace("'", '')
#print(all_data.tail())

# %% [markdown]
# <h2>Figure below shows the #5 Li-ion charge and discharge process in one cycle.</h2>
# <p>The graph explain the current battery and voltage battery in both charge and discharge operation.</p>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Create some mock data

fig, ax1 = plt.subplots()
sns.set_style("white")
plot_df= all_data.loc[(all_data['cycle']==1),['time','current_battery']]
#plt.plot([126, 127], color="black")
plot_df1 = all_data.loc[(all_data['cycle']==1),['time','voltage_battery']]

color = 'tab:red'
ax1.set_xlabel('time (in min)')
ax1.set_ylabel('voltage battery', color=color)
ax1.plot(plot_df1['time'], plot_df1['voltage_battery'], color=color,label='voltage battery')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('current battery', color=color)  # we already handled the x-label with ax1
ax2.plot(plot_df['time'], plot_df['current_battery'],'-', color=color, label='current battery')
ax2.tick_params(axis='y', labelcolor=color)
fig.set_size_inches(10, 5)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# vertical black line split the graph between charge and discharge operation.
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# <p style="font-size:16px">The figure below explain<i><u>(the cylces of B0005)</u></i> that after long-term, repeated charges and discharges, the lifetime of the Li-ion battery will be gradually reduced due to some irreversible reactions.</p>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plot_df = discharge.loc[(discharge['cycle']==10),['time','voltage_battery']]
plot_df1 = discharge.loc[(discharge['cycle']==100),['time','voltage_battery']]
#lot_df2 = discharge.loc[(discharge['cycle']==120),['time','voltage_battery']]
plot_df3 = discharge.loc[(discharge['cycle']==50),['time','voltage_battery']]
plot_df4 = discharge.loc[(discharge['cycle']==160),['time','voltage_battery']]


sns.set_style("white")
plt.figure(figsize=(10, 5))
plt.plot(plot_df['time'], plot_df['voltage_battery'],color='red',linewidth=1, alpha=0.9, label='Cycle 10')
plt.plot(plot_df1['time'], plot_df1['voltage_battery'],'-',color='blue',linewidth=1, alpha=0.9, label='Cycle 100')
#lt.plot(plot_df2['time'], plot_df2['voltage_battery'],color='green',linewidth=1, alpha=0.9, label='Cycle 120')
plt.plot(plot_df3['time'], plot_df3['voltage_battery'],'-',color='black',linewidth=1, alpha=0.9, label='Cycle 50')
plt.plot(plot_df4['time'], plot_df4['voltage_battery'],color='Orange',linewidth=1, alpha=0.9, label='Cycle 160')


plt.ylabel('voltage battery')

# make x-axis ticks legible
plt.legend(loc='upper right', ncol=2,)
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('Time (sec)')
plt.title('Discharge')
# Out:
# Text(0.5, 1.0, 'Discharge')

# %% [markdown]
# After analysing all datasets we find the data is heterogeneous because it is sourced from different batteries that have operated under varying temperature, current, voltage and load condition.

# %%
print(dis_ele.head())
# Out:
#   Batt_name  cycle      time  Capacity
# 0  B0005_10      1  3690.234  1.856487
# 1  B0005_10      2  3672.344  1.846327
# 2  B0005_10      3  3651.641  1.835349
# 3  B0005_10      4  3631.563  1.835263
# 4  B0005_10      5  3629.172  1.834646

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plot_df = dis_ele.loc[(dis_ele['cycle']>=1),['cycle','time']]
sns.set_style("darkgrid")
plt.figure(figsize=(8, 5))
plt.plot(plot_df['cycle'], plot_df['time'])
#Draw threshold
#plt.plot(dis['cycle'], dis['limt']) 'g'
plt.ylabel('time')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('cycle')
plt.title('Discharge B0005 - Orange line: charge and  Blue line: Discharge')
# Out:
# Text(0.5, 1.0, 'Discharge B0005 - Orange line: charge and  Blue line: Discharge')

# %%
j=0
del1=0.0
del2=0.0
cycle=0
k=0
#cc=discharge['cycle'][0]
for i in range(len(discharge)):
    cc=discharge['cycle'][i]
    
    if cc==cycle:
        j=j+1
        if j==1:
            #print(cycle)
            deltaV=discharge['voltage_battery'][i]-discharge['voltage_battery'][i+1]
            current = abs(discharge["current_battery"][i+1])
            resistance=deltaVcurrent
            #print(str(k)+"    " +str(resistance))
            dis_ele['resistance'][k]=resistance
            k=k+1
            j=j+1
    else:
        cycle=discharge['cycle'][i]
        j=0

# %%
print(dis_ele.head(168))
# Out:
#     Batt_name  cycle      time  Capacity       SoH  resistance
# 0    B0005_10      1  3690.234  1.856487  1.000000    0.107267
# 1    B0005_10      2  3672.344  1.846327  0.994527    0.104100
# 2    B0005_10      3  3651.641  1.835349  0.988614    0.102806
# 3    B0005_10      4  3631.563  1.835263  0.988567    0.102472
# 4    B0005_10      5  3629.172  1.834646  0.988235    0.101852
# 5    B0005_10      6  3652.281  1.835662  0.988782    0.101600
# 6    B0005_10      7  3650.828  1.835146  0.988504    0.100771
# 7    B0005_10      8  3572.453  1.825757  0.983447    0.100349
# 8    B0005_10      9  3550.594  1.824774  0.982917    0.100022
# 9    B0005_10     10  3551.250  1.824613  0.982831    0.100228
# 10   B0005_10     11  3530.250  1.824620  0.982834    0.100215
# 11   B0005_10     12  3491.016  1.814202  0.977223    0.099396
# 12   B0005_10     13  3470.281  1.813752  0.976981    0.099412
# 13   B0005_10     14  3470.000  1.813440  0.976813    0.099694
# 14   B0005_10     15  3450.297  1.802598  0.970972    0.099696
# 15   B0005_10     16  3429.407  1.802107  0.970708    0.099741
# 16   B0005_10     17  3409.484  1.802579  0.970962    0.099515
# 17   B0005_10     18  3390.422  1.803068  0.971226    0.099571
# 18   B0005_10     19  3390.281  1.802778  0.971069    0.099558
# 19   B0005_10     20  3591.734  1.847026  0.994904    0.099586
# 20   B0005_10     21  3552.297  1.847417  0.995114    0.099105
# 21   B0005_10     22  3531.578  1.836177  0.989060    0.099245
# 22   B0005_10     23  3492.907  1.825781  0.983460    0.099650
# 23   B0005_10     24  3511.594  1.825114  0.983100    0.099758
# 24   B0005_10     25  3431.937  1.825581  0.983352    0.099667
# 25   B0005_10     26  3431.125  1.814031  0.977131    0.099757
# 26   B0005_10     27  3412.406  1.814769  0.977528    0.100023
# 27   B0005_10     28  3410.688  1.813969  0.977098    0.100081
# 28   B0005_10     29  3410.718  1.802766  0.971063    0.100001
# 29   B0005_10     30  3392.719  1.804077  0.971769    0.100056
# ..        ...    ...       ...       ...       ...         ...
# 138  B0005_10    139  2874.234  1.354704  0.729713    0.107805
# 139  B0005_10    140  2864.984  1.349315  0.726811    0.108279
# 140  B0005_10    141  2855.093  1.344189  0.724050    0.108901
# 141  B0005_10    142  2855.625  1.338991  0.721250    0.109465
# 142  B0005_10    143  2855.594  1.338915  0.721209    0.109108
# 143  B0005_10    144  2847.437  1.334007  0.718565    0.109208
# 144  B0005_10    145  2847.360  1.328644  0.715677    0.109592
# 145  B0005_10    146  2837.328  1.323171  0.712728    0.110451
# 146  B0005_10    147  2837.281  1.318169  0.710034    0.110999
# 147  B0005_10    148  2838.515  1.318466  0.710194    0.110097
# 148  B0005_10    149  2828.328  1.318293  0.710101    0.110257
# 149  B0005_10    150  2838.265  1.323872  0.713106    0.111594
# 150  B0005_10    151  2864.547  1.360122  0.732632    0.108237
# 151  B0005_10    152  2846.390  1.339531  0.721540    0.109221
# 152  B0005_10    153  2837.969  1.329029  0.715883    0.109852
# 153  B0005_10    154  2838.156  1.323674  0.712999    0.110203
# 154  B0005_10    155  2829.843  1.318634  0.710284    0.110693
# 155  B0005_10    156  2829.625  1.313475  0.707506    0.110850
# 156  B0005_10    157  2819.437  1.313202  0.707358    0.111014
# 157  B0005_10    158  2819.579  1.307796  0.704446    0.111260
# 158  B0005_10    159  2810.672  1.303033  0.701881    0.111719
# 159  B0005_10    160  2811.485  1.303357  0.702056    0.111591
# 160  B0005_10    161  2802.422  1.303410  0.702084    0.111547
# 161  B0005_10    162  2801.625  1.297887  0.699109    0.111572
# 162  B0005_10    163  2802.031  1.298074  0.699209    0.112101
# 163  B0005_10    164  2793.390  1.293464  0.696726    0.112087
# 164  B0005_10    165  2793.390  1.288003  0.693785    0.112118
# 165  B0005_10    166  2792.485  1.287453  0.693488    0.112121
# 166  B0005_10    167  2802.016  1.309015  0.705103    0.109285
# 167  B0005_10    168  2820.390  1.325079  0.713756    0.108801
#
# [168 rows x 6 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plot_df = dis_ele.loc[(dis_ele['cycle']>=1),['cycle','resistance']]
sns.set_style("darkgrid")
plt.figure(figsize=(10, 8))
plt.plot(plot_df['cycle'], plot_df['resistance'])
#Draw threshold
#plt.plot([0.,len(dis)], [1.4, 1.4])
plt.ylabel('resistance')
# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
plt.xlabel('cycle')
plt.title('Discharge B0005')
# Out:
# Text(0.5, 1.0, 'Discharge B0005')

# %%
# plot a heatmap to display +ve and -ve correlation among features and regression label:
featurs=['voltage_battery','current_battery','temp_battery','current_load','voltage_load','time']
import seaborn as sns
cm = np.corrcoef(discharge[featurs].values.T)
sns.set(font_scale=1.0)
fig = plt.figure(figsize=(10, 8))
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 8}, yticklabels=featurs, xticklabels=featurs)
plt.title('Features Correlation Heatmap')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline  

from pandas.tools.plotting import scatter_matrix
sns.reset_orig()
scatter_matrix(dis_ele, alpha=0.2, figsize=(20, 20), diagonal='kde')
# Out:
# /home/khaled/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /home/khaled/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
# /home/khaled/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   if __name__ == '__main__':
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd510b54710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5104846a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5104acbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd51045c198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd510480710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd510428c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5103da240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5103837f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd510383828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd51035c2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd510303828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd51032cda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd5102dd358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5102848d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd5102ace48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd510907a58>]],
#       dtype=object)

# %%
dis_H=pd.read_csv('Discharge5_H.csv')

# %%
print(dis_H.head())
# Out:
#    Unnamed: 0 Batt_name  cycle             dateTime  amb_temp  \
# 0           0  B0005_10      1  2008-04-02 15:25:41        24
# 1           1  B0005_10      2  2008-04-02 19:43:48        24
# 2           2  B0005_10      3  2008-04-03 00:01:06        24
# 3           3  B0005_10      4  2008-04-03 04:16:37        24
# 4           4  B0005_10      5  2008-04-03 08:33:25        24
#
#    voltage_battery  current_battery  temp_battery  voltage_load  current_load  \
# 0         3.277170        -0.006528     34.230853           0.0       -0.0006
# 1         3.300245        -0.000448     34.392137           0.0       -0.0006
# 2         3.327451         0.001026     34.232779           0.0       -0.0006
# 3         3.314182        -0.002234     34.413450           0.0       -0.0006
# 4         3.305497         0.000009     34.345885           0.0       -0.0006
#
#        time  Capacity         H
# 0  3690.234  1.856487  2421.438
# 1  3672.344  1.846327  2423.500
# 2  3651.641  1.835349  2423.719
# 3  3631.563  1.835263  2406.093
# 4  3629.172  1.834646  2404.578

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plot_df = dis_H.loc[(dis_H['cycle']>=1),['cycle','H']]
sns.set_style("darkgrid")
plt.figure(figsize=(8, 5))
plt.plot(plot_df['cycle'], plot_df['H'])
#Draw threshold
#plt.plot(dis['cycle'], dis['limt']) 'g'
plt.ylabel('time')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('cycle')
plt.title('Discharge B0005 - Orange line: charge and  Blue line: Discharge')
# Out:
# Text(0.5, 1.0, 'Discharge B0005 - Orange line: charge and  Blue line: Discharge')

# %%
dis_H=pd.read_csv('Discharge6_H.csv')
dis_H.dtypes
# Out:
# Unnamed: 0           int64
# Batt_name           object
# cycle                int64
# dateTime            object
# amb_temp             int64
# voltage_battery    float64
# current_battery    float64
# temp_battery       float64
# voltage_load       float64
# current_load       float64
# time               float64
# Capacity           float64
# H                  float64
# dtype: object

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
plot_df = dis_H.loc[(dis_H['cycle']>=1),['cycle','H']]
plot_df1 = dis_H.loc[(dis_H['cycle']>=1),['cycle','Capacity']]
plt.plot(plot_df1['cycle'], plot_df1['Capacity'], color='red')
plt.title('Discharge B0006 - With Capacity')

sns.set_style("darkgrid")
plt.figure(figsize=(8, 5))
plt.plot(plot_df['cycle'], plot_df['H'])
#plt.plot(plot_df1['cycle'], plot_df1['Capacity'], color='red')

#Draw threshold
#plt.plot(dis['cycle'], dis['limt']) 'g'
plt.ylabel('time')

# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('cycle')
plt.title('Discharge B0006 - Cycle with Time interval')
# Out:
# Text(0.5, 1.0, 'Discharge B0006 - Cycle with Time interval')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plot_df = discharge.loc[(discharge['cycle']==10),['time','current_battery']]
plot_df1 = discharge.loc[(discharge['cycle']==100),['time','current_battery']]
plot_df2 = discharge.loc[(discharge['cycle']==120),['time','current_battery']]
plot_df3 = discharge.loc[(discharge['cycle']==150),['time','current_battery']]
plot_df4 = discharge.loc[(discharge['cycle']==160),['time','current_battery']]


sns.set_style("white")
plt.figure(figsize=(20, 8))
plt.plot(plot_df['time'], plot_df['current_battery'],color='red',label='Cycle 10')
plt.plot(plot_df1['time'], plot_df1['current_battery'],'-',color='blue',label='Cycle 10')
plt.plot(plot_df2['time'], plot_df2['current_battery'],color='green',label='Cycle 10')
plt.plot(plot_df3['time'], plot_df3['current_battery'],'-',color='black',label='Cycle 10')
plt.plot(plot_df4['time'], plot_df4['current_battery'],color='Orange',label='Cycle 10')


plt.ylabel('current battery')

# make x-axis ticks legible
plt.legend(loc='upper center', ncol=2,)
adf = plt.gca().get_xaxis().get_major_formatter()
#adf.scaled[1.0] = '%m-%d-%Y'
plt.xlabel('Time')
plt.title('Discharge')
print(" cycle 10 with color:red\n cycle 100 with color: blue\n cycle 120 with color:green\n cycle 150 with color: black\n cycle 160 with color: orange")
# Out:
#  cycle 10 with color:red
#  cycle 100 with color: blue
#  cycle 120 with color:green
#  cycle 150 with color: black
#  cycle 160 with color: orange

# %%
dis = pd.read_csv('Capacity_onlineB5.csv')
print(dis.tail())
# Out:
#      Unnamed: 0 Batt_name  cycle                dateTime  amb_temp  \
# 163         163     B0005    164   '2008-05-26 10:44:38'        24
# 164         164     B0005    165   '2008-05-26 15:30:43'        24
# 165         165     B0005    166   '2008-05-26 20:21:04'        24
# 166         166     B0005    167   '2008-05-27 15:52:41'        24
# 167         167     B0005    168   '2008-05-27 20:45:42'        24
#
#      voltage_battery  temp_battery  current_battery      time  Capacity_online
# 163         2.668737     40.864674        -2.011053  2327.578         1.292325
# 164         2.696396     40.857545        -2.014212  2318.109         1.287053
# 165         2.679483     40.937025        -2.012752  2316.938         1.286416
# 166         2.678714     40.936092        -2.014447  2355.609         1.308020
# 167         2.655378     40.873909        -2.014372  2383.953         1.323923

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plot_df = dis.loc[(dis['cycle']>=1),['cycle','temp_battery']]
sns.set_style("darkgrid")
plt.figure(figsize=(12, 8))
plt.plot(plot_df['cycle'], plot_df['temp_battery'])
#Draw threshold
plt.ylabel('temp_battery')
# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
plt.xlabel('cycle')
plt.title('Discharge B0005')
# Out:
# Text(0.5, 1.0, 'Discharge B0005')
