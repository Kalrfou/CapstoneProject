# %% [markdown]
# <b>The code below used STLM by using only Capacity field to predict the RUL(STLM using one variable with multisteps)</b>
# <p>We built the model only on Battery B0006</p>

# %%
import sys 
import numpy as np # linear algebra
from scipy.stats import randint
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv), data manipulation as in SQL
import matplotlib.pyplot as plt # this is used for the plot the graph 
import seaborn as sns # used for plot interactive graph. 
from sklearn.model_selection import train_test_split # to split the data into two parts
#from sklearn.cross_validation import KFold # use for cross validation
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline # pipeline making
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error,r2_score

## for Deep-learing:
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.utils import to_categorical
from keras.optimizers import SGD 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import itertools
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
df=pd.read_csv("B0005_on.csv")
#featurs=['Batt_name','cycle','amb_temp','voltage_battery','current_battery','temp_battery','current_load','voltage_load','time','Capacity','NewCap']
f1=['cycle','NewCap']
df=df[f1]
#dataset=df[(df.Batt_name =='B0005')| (df.Batt_name =='B0006') | (df.Batt_name =='B0007')|(df.Batt_name =='B0018')]
# Feature Selection
#dataset=df[(df['Batt_name']=='B0006_11')]
dataset=df#<70 need window to be 10
#dataset=dataset[f1]
data_train=dataset[(dataset['cycle']<50)]
data_set_train=data_train.iloc[:,1:2].values
data_test=dataset[(dataset['cycle']>=50)]
data_set_test=data_test.iloc[:,1:2].values

from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
data_set_train=sc.fit_transform(data_set_train)
data_set_test=sc.transform(data_set_test)

X_train=[]
y_train=[]
#take the last 10t to predict 10t+1
for i in range(10,49):
    X_train.append(data_set_train[i-10:i,0])
    y_train.append(data_set_train[i,0])
X_train,y_train=np.array(X_train),np.array(y_train)
 
X_train=np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))

# %% [markdown]
# <h1> Applied STLM </h3>

# %%
regress=Sequential()
regress.add(LSTM(units=200, return_sequences=True, input_shape=(X_train.shape[1],1)))
regress.add(Dropout(0.3))

regress.add(LSTM(units=200, return_sequences=True))
regress.add(Dropout(0.3))


regress.add(LSTM(units=200, return_sequences=True))
regress.add(Dropout(0.3))

regress.add(LSTM(units=200))
regress.add(Dropout(0.3))


regress.add(Dense(units=1))

regress.compile(optimizer='adam',loss='mean_squared_error')

regress.fit(X_train,y_train,epochs=200,batch_size=25)
# Out:
# Epoch 1/200
# 39/39 [==============================] - 5s 138ms/step - loss: 0.3201
# Epoch 2/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1808
# Epoch 3/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0679
# Epoch 4/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0543
# Epoch 5/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0694
# Epoch 6/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0793
# Epoch 7/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0498
# Epoch 8/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0456
# Epoch 9/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0670
# Epoch 10/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0452
# Epoch 11/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0521
# Epoch 12/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0606
# Epoch 13/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0437
# Epoch 14/200
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0485
# Epoch 15/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0482
# Epoch 16/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0479
# Epoch 17/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0408
# Epoch 18/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0465
# Epoch 19/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0462
# Epoch 20/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0394
# Epoch 21/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0411
# Epoch 22/200
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0423
# Epoch 23/200
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0436
# Epoch 24/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0411
# Epoch 25/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0412
# Epoch 26/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0403
# Epoch 27/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0430
# Epoch 28/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0383
# Epoch 29/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0416
# Epoch 30/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0372
# Epoch 31/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0333
# Epoch 32/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0351
# Epoch 33/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0356
# Epoch 34/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0372
# Epoch 35/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0344
# Epoch 36/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0392
# Epoch 37/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0346
# Epoch 38/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0380
# Epoch 39/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0407
# Epoch 40/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0405
# Epoch 41/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0313
# Epoch 42/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0398
# Epoch 43/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0363
# Epoch 44/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0435
# Epoch 45/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0410
# Epoch 46/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0384
# Epoch 47/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0428
# Epoch 48/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0319
# Epoch 49/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0391
# Epoch 50/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0359
# Epoch 51/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0416
# Epoch 52/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0332
# Epoch 53/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0446
# Epoch 54/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0403
# Epoch 55/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0386
# Epoch 56/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0417
# Epoch 57/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0320
# Epoch 58/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0365
# Epoch 59/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0365
# Epoch 60/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0350
# Epoch 61/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0364
# Epoch 62/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0360
# Epoch 63/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0406
# Epoch 64/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0341
# Epoch 65/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0348
# Epoch 66/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0345
# Epoch 67/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0317
# Epoch 68/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0347
# Epoch 69/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0364
# Epoch 70/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0367
# Epoch 71/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0308
# Epoch 72/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0387
# Epoch 73/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0403
# Epoch 74/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0390
# Epoch 75/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0339
# Epoch 76/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0392
# Epoch 77/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0297
# Epoch 78/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0405
# Epoch 79/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0387
# Epoch 80/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0342
# Epoch 81/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0342
# Epoch 82/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0326
# Epoch 83/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0322
# Epoch 84/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0334
# Epoch 85/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0333
# Epoch 86/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0406
# Epoch 87/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0355
# Epoch 88/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0337
# Epoch 89/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0339
# Epoch 90/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0340
# Epoch 91/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0351
# Epoch 92/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0403
# Epoch 93/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0403
# Epoch 94/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0319
# Epoch 95/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0324
# Epoch 96/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0346
# Epoch 97/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0356
# Epoch 98/200
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0325
# Epoch 99/200
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0333
# Epoch 100/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0301
# Epoch 101/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0326
# Epoch 102/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0279
# Epoch 103/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0269
# Epoch 104/200
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0277
# Epoch 105/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0316
# Epoch 106/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0319
# Epoch 107/200
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0294
# Epoch 108/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0320
# Epoch 109/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0319
# Epoch 110/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0298
# Epoch 111/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0250
# Epoch 112/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0290
# Epoch 113/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0310
# Epoch 114/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0273
# Epoch 115/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0337
# Epoch 116/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0364
# Epoch 117/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0334
# Epoch 118/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0290
# Epoch 119/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0294
# Epoch 120/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0285
# Epoch 121/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0432
# Epoch 122/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0344
# Epoch 123/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0422
# Epoch 124/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0254
# Epoch 125/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0425
# Epoch 126/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0307
# Epoch 127/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0330
# Epoch 128/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0324
# Epoch 129/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0298
# Epoch 130/200
# 39/39 [==============================] - 0s 4ms/step - loss: 0.0312
# Epoch 131/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0296
# Epoch 132/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0274
# Epoch 133/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0291
# Epoch 134/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0286
# Epoch 135/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0257
# Epoch 136/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0303
# Epoch 137/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0315
# Epoch 138/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0281
# Epoch 139/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0302
# Epoch 140/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0278
# Epoch 141/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0345
# Epoch 142/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0250
# Epoch 143/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0310
# Epoch 144/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0323
# Epoch 145/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0260
# Epoch 146/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0310
# Epoch 147/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0268
# Epoch 148/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0257
# Epoch 149/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 150/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0288
# Epoch 151/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0263
# Epoch 152/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0234
# Epoch 153/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0237
# Epoch 154/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0230
# Epoch 155/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0247
# Epoch 156/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0283
# Epoch 157/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0240
# Epoch 158/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0262
# Epoch 159/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 160/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0229
# Epoch 161/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0235
# Epoch 162/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 163/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0288
# Epoch 164/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0259
# Epoch 165/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0278
# Epoch 166/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0243
# Epoch 167/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0290
# Epoch 168/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0202
# Epoch 169/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0278
# Epoch 170/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0301
# Epoch 171/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0242
# Epoch 172/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0235
# Epoch 173/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0237
# Epoch 174/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 175/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0222
# Epoch 176/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0267
# Epoch 177/200
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0245
# Epoch 178/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0262
# Epoch 179/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0211
# Epoch 180/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0220
# Epoch 181/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0254
# Epoch 182/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0244
# Epoch 183/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0271
# Epoch 184/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0251
# Epoch 185/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0203
# Epoch 186/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0283
# Epoch 187/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0297
# Epoch 188/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0231
# Epoch 189/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0277
# Epoch 190/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 191/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0280
# Epoch 192/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0281
# Epoch 193/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0294
# Epoch 194/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0226
# Epoch 195/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0265
# Epoch 196/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0284
# Epoch 197/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0223
# Epoch 198/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 199/200
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0239
# Epoch 200/200
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0247

# %% [markdown]
# <h1> Test the Model that was built by STLM</h1>

# %%
len(data_test)
# Out:
# 119

# %%
#### predictions
data_total=pd.concat((data_train['NewCap'],data_test['NewCap']),axis=0)
inputs=data_total[len(data_total)-len(data_test)-10:].values
inputs=inputs.reshape(-1,1)
inputs=sc.transform(inputs)

# %%
X_test=[]
for i in range(10,129):
    X_test.append(inputs[i-10:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

pred=regress.predict(X_test)
pred=sc.inverse_transform(pred)
pred=pred[:,0]
tests=data_test.iloc[:,1:2]
rmse = np.sqrt(mean_squared_error(tests, pred))
print('Test RMSE: %.3f' % rmse)

metrics.r2_score(tests,pred)
# Out:
# Test RMSE: 0.048
# 0.8744240185461767

# %%
len(pred)
data_test['pre']=pred
#print(data_test.head(50))
# Out:
# /home/khaled/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plot_df = dataset.loc[(dataset['cycle']>=1),['cycle','NewCap']]
plot_per=data_test.loc[(data_test['cycle']>=70),['cycle','pre']]
sns.set_style("darkgrid")
plt.figure(figsize=(8, 8))
plt.plot(plot_df['cycle'], plot_df['NewCap'], label="Actual data", color='blue')
plt.plot(plot_per['cycle'],plot_per['pre'],label="Prediction data", color='red')
#plt.plot(pred)
#Draw threshold
plt.plot([0.,168], [1.38, 1.38],dashes=[6, 2])
plt.ylabel('NewCap')
# make x-axis ticks legible
adf = plt.gca().get_xaxis().get_major_formatter()
plt.xlabel('cycle')
plt.title('Discharge B0005 (prediction)start in cycle 50 -RULe=-1, window-size=10')
# Out:
# Text(0.5, 1.0, 'Discharge B0005 (prediction)start in cycle 50 -RULe=-1, window-size=10')

# %%
actual=0
pred=0
Afil=0
Pfil=0
a=data_test['NewCap'].values
b=data_test['pre'].values
j=0
k=0
for i in range(len(a)):
    actual=a[i]
    
    if actual<=1.38:
        j=i
        Afil=j
        break
for i in range(len(a)):
    pred=b[i]
    if pred< 1.38:
        k=i
        Pfil=k
        break
print("The Actual fail at cycle number: "+ str(Afil+89))
print("The prediction fail at cycle number: "+ str(Pfil+89))
# Out:
# The Actual fail at cycle number: 168
# The prediction fail at cycle number: 169

# %%
RULerror=Pfil-Afil
print("The error of RUL= "+ str(RULerror)+ " Cycle(s)")
# Out:
# The error of RUL= 1 Cycle(s)

# %% [markdown]
# <h4> The LSTM model with(one input layer, 3 hidden layer and 1 output layer, and each layer with 200 neurons) the
#     results below show the prediction in different number of cycles.</h4>
#  <h4> when the training dataset less than 70 cycles, we need to adjust the window(lage) to 10 rather than 5.</h4>

# %% [markdown]
# <tabel>
#     <tr>
#         <td><img src="https://github.com/Kalrfou/CapstoneProject/tree/master/Online/Cycle110-w5.png"></td>
#         <td><img src="https://github.com/Kalrfou/CapstoneProject/tree/master/Online/Cycle100-w5.png"></td>
#   </tr>
#      <tr>
#         <td><img src="https://github.com/Kalrfou/CapstoneProject/tree/master/Online/Cycle80-w5.png"></td>
#         <td><img src="https://github.com/Kalrfou/CapstoneProject/tree/master/Online/Cycle50-w10.png"></td>
#   </tr>
# </tabel>
